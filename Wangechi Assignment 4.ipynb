# %%
#Kaggle: Telco Customer Churn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
Kaggle=pd.read_csv(r"C:\Users\Admin\Desktop\ADS\Assignment\Assignment 4\WA_Fn-UseC_-Telco-Customer-Churn.csv")
Kaggle
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
Kaggle.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
#1. Demographic:
#a. Which 2 demographics have proven to be the most popular with the telco brand?
Kaggle_ChurnNo=Kaggle[Kaggle['Churn'] =='No']
Kaggle_ChurnNo
Kaggle_ChurnNo[['gender','SeniorCitizen','Partner','Dependents']].apply(pd.Series.value_counts)
print ("SeniorCitizen = 0 and Dependents = NO")
# Out:
# SeniorCitizen = 0 and Dependents = NO

# %%
#b. If the marketing team wanted to increase customer retention, to whom should they target their advertisements to?
Kaggle_ChurnYes=Kaggle[Kaggle['Churn'] =='Yes']
Kaggle_ChurnYes
Kaggle_ChurnYes[['gender','SeniorCitizen','Partner','Dependents']].apply(pd.Series.value_counts)
print ("SeniorCitizen = 0, Partner = No and Dependents = No")
# Out:
# SeniorCitizen = 0, Partner = No and Dependents = No

# %%
#2. Services:
#a. Which 3 services are contributing to a higher monthly charge and resulting to customers churning? 
#(Use visualizations in explaining your analysis)
churn_Yes = Kaggle[['PhoneService', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'MonthlyCharges', 'Contract', 'Churn']][Kaggle['Churn'] == "Yes"]

churn_Yes[:5]
# Out:
#    PhoneService InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 2           Yes             DSL            Yes          Yes               No
# 4           Yes     Fiber optic             No           No               No
# 5           Yes     Fiber optic             No           No              Yes
# 8           Yes     Fiber optic             No           No              Yes
# 13          Yes     Fiber optic             No          Yes              Yes
#
#    TechSupport StreamingTV StreamingMovies  MonthlyCharges        Contract  \
# 2           No          No              No           53.85  Month-to-month
# 4           No          No              No           70.70  Month-to-month
# 5           No         Yes             Yes           99.65  Month-to-month
# 8          Yes         Yes             Yes          104.80  Month-to-month
# 13          No         Yes             Yes          103.70  Month-to-month
#
#    Churn
# 2    Yes
# 4    Yes
# 5    Yes
# ...

# %%
Kaggle['MonthlyCharges'].max()
Kaggle_mxpx = Kaggle[['PhoneService','InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection','TechSupport',
                    'StreamingTV','StreamingMovies','MonthlyCharges', 'Churn']][Kaggle['MonthlyCharges'] == 118.75]
Kaggle_mxpx

for col in ['PhoneService', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection','TechSupport','StreamingTV', 
            'StreamingMovies']:
        plt.figure(figsize=(8,5))
        sns.barplot(x=col, y='MonthlyCharges', hue='Churn', data=Kaggle)
        plt.show()

# %%
#b. If the telco was to offer Phone as a standalone service, which type of contract would encourage customer retention?
sns.countplot(x="PhoneService", hue="Contract", data=Kaggle)
plt.xlabel("PhoneService")
plt.ylabel("No of subscribers")
# Out:
# Text(0, 0.5, 'No of subscribers')

# %%
#3. Payment: (Use visualizations in explaining your analysis)
#a. If the company was to streamline all its services into 3 bouquet packages, what 
#monthly prices will be appropriate for the following packages to keep customers from churning:
#i. Basic
#ii. Plus
#iii. Premium
#b. Should the company strictly go paperless for their monthly billings as a technique of keeping their customers and why?

Kaggle.groupby(['MonthlyCharges','Churn']).count().reset_index()
# Out:
#       MonthlyCharges Churn  customerID  gender  SeniorCitizen  Partner  \
# 0              18.25    No           1       1              1        1
# 1              18.40    No           1       1              1        1
# 2              18.55    No           1       1              1        1
# 3              18.70    No           2       2              2        2
# 4              18.75    No           1       1              1        1
# ...              ...   ...         ...     ...            ...      ...
# 2365          118.20    No           1       1              1        1
# 2366          118.35   Yes           1       1              1        1
# 2367          118.60    No           2       2              2        2
# 2368          118.65    No           1       1              1        1
# 2369          118.75    No           1       1              1        1
#
#       Dependents  tenure  PhoneService  MultipleLines  ...  OnlineSecurity  \
# ...

# %%
Kaggle['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
#If the company was to streamline all its services into 3 bouquet packages, 
#what monthly prices will be appropriate for the following packages to keep customers from churning:
#i. Basic, ii. Plus, iii. Premium

sns.histplot(x="MonthlyCharges", hue ="Churn", data=Kaggle, kde=True,)
plt.xlabel("MonthlyCharges")
# Out:
# Text(0.5, 0, 'MonthlyCharges')

# %%
#Should the company strictly go paperless for their monthly billings as a technique of keeping their customers and why?
plt.figure(figsize=(10,5))
sns.countplot(x="PaperlessBilling", hue="Churn", data=Kaggle)
plt.xlabel("PaperlessBilling")
plt.ylabel("No of subscribers")
# Out:
# Text(0, 0.5, 'No of subscribers')

# %%
print("No,Clients no using paperless would more likely to churn.")
# Out:
# No,Clients no using paperless would more likely to churn.
